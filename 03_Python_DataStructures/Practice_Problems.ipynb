# %% [markdown]
# ## Practice Problems

# %% [markdown]
# ### Problem 1
#
# Find the largest number.

# %%
# nums = [12,45,67,23,89]
# lar_nums=[]
# lar_nums+=nums
# lar_nums.sort()
# print(lar_nums[-1])

#or
nums = [12,45,67,23,89]
largest = max(nums)
largest
# Out:
# 89

# %% [markdown]
# ### Problem 2
# Find the average.

# %%
import statistics as st
marks = [67,87,89,90,76]
average=st.mean(marks)
average
# Out:
# 81.8

# %% [markdown]
# ### Problem 3
#
# Reverse a list without using reverse().

# %%
marks = [67,87,89,90,76]
marks[: : -1]
# Out:
# [76, 90, 89, 87, 67]

# %% [markdown]
# ### Problem 4
#
# Count even numbers.

# %%
nums = [1,2,3,4,5,6,7,8]
even_num = sum(1 for i in nums if i%2==0 )
even_num
# Out:
# 4

# %% [markdown]
# ## Dictionaries
# ### Problem 5
#
# Print all keys.

# %%
student = {
    "name":"Yuvasree",
    "age":22,
    "score":89
}
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'score'])

# %% [markdown]
# ### Problem 6
#
# Find student with highest score.

# %%
scores = {
    "A":80,
    "B":90,
    "C":85
}
high_score = max(scores, key=scores.get)
high_score
# Out:
# 'B'

# %%
nums = [1,2,2,3,3,4,5]
unique_nums = set(nums)
unique_nums
# Out:
# {1, 2, 3, 4, 5}

# %%
sql = {"A","B","C"}

python = {"B","C","D"}
common= sql.intersection(python)
common
# Out:
# {'B', 'C'}
