# %% [markdown]
# ## Built-In Data Structures
# - to collect multiple data in a structure
#
# ## Data Structures in python
# 1.List
#
# 2.Sets
#
# 3.Tuples
#
# 4.Dictionary - Key,value pairs

# %% [markdown]
# ### 1.LIST- [ ]:
# - List shows duplicates values
# - 1 dimensional 1D
# - stores Heterogenous datatype values
# - Can be mutuable
# - Indexing & Slicing can be done

# %%
empty_cart=[]
type(empty_cart)
# Out:
# list

# %%
Items_to_buy=["apple","grape","orange","pineapple,apple",6.75,0,9]
Items_to_buy
# Out:
# ['apple', 'grape', 'orange', 'pineapple,apple', 6.75, 0, 9]

# %%
type(Items_to_buy)
# Out:
# list

# %%
print(Items_to_buy[-1]) #negative indexing
print(Items_to_buy[0]) #positive indexing

print(Items_to_buy[0:2]) #positive slicing
print(Items_to_buy[3:])

print(Items_to_buy[-6:-2]) #negative slicing 
print(Items_to_buy[::-1]) #reverse list using slicing

print(Items_to_buy[0::2])  #[start:stop:step]
print(Items_to_buy[0:len(Items_to_buy):1])
# Out:
# 9
# apple
# ['apple', 'grape']
# ['pineapple,apple', 6.75, 0, 9]
# ['grape', 'orange', 'pineapple,apple', 6.75]
# [9, 0, 6.75, 'pineapple,apple', 'orange', 'grape', 'apple']
# ['apple', 'orange', 6.75, 9]
# ['apple', 'grape', 'orange', 'pineapple,apple', 6.75, 0, 9]

# %%
Items_to_buy[1]="watermelon"
print(Items_to_buy[1]) #mutable
# Out:
# watermelon

# %% [markdown]
# #### 2.Sets - {}:
# - 1D
# - Hetrogenous
# - Removes duplicate values
# - Can be Mutable
# - Indexing and slicing is not possible

# %%
Items_to_buy_2 = {"apple","grape","orange","pineapple,apple",6.75,0,9}
type(Items_to_buy_2)
# Out:
# set

# %%
Items_to_buy_2
# Out:
# {0, 6.75, 9, 'apple', 'grape', 'orange', 'pineapple,apple'}

# %%
Items_to_buy_2.add("banana")
print(Items_to_buy_2)
Items_to_buy_2  #give result in ascending order first numbers
# Out:
# {0, 'grape', 6.75, 'apple', 'orange', 9, 'banana', 'pineapple,apple'}
# {0, 6.75, 9, 'apple', 'banana', 'grape', 'orange', 'pineapple,apple'}
