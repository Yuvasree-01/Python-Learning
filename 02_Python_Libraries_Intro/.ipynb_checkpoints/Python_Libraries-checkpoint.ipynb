# %% [markdown]
# ## Libraries
#
# It is a set of functions,modules and classes where ot has some pre-written codes to perform some tasks

# %% [markdown]
# # 1. Pandas Library
# - for Data Analysis

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd #aliases

# %% [markdown]
# #### Importing file from different folder or location

# %%
pd.read_csv(filepath_or_buffer = r"D:\Data_Analyst_Prep\insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ##### If the text file is not in our current working folder,It's in different folder we can simply use the--> r"file directory path of the text file\text_file_name.extension"
#
# Giving r before "" can omit unicode error

# %% [markdown]
# #### Importing file from working folder

# %%
insurance_charges = pd.read_csv(filepath_or_buffer = "insurance.csv")

# %%
insurance_charges
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## 2.Numpy Library
# Numerical Operations

# %%
import numpy as np

# %%
np.repeat(a = insurance_charges, repeats=2,axis=0)
# Out:
# array([[19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [18, 'male', 33.77, ..., 'no', 'southeast', 1725.5523],
#        ...,
#        [21, 'female', 25.8, ..., 'no', 'southwest', 2007.945],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603]],
#       shape=(2676, 7), dtype=object)

# %%
updates_insurance_data= pd.DataFrame(data=np.repeat(a=insurance_charges,repeats=2,axis=0))
updates_insurance_data
# Out:
#        0       1      2  3    4          5           6
# 0     19  female   27.9  0  yes  southwest   16884.924
# 1     19  female   27.9  0  yes  southwest   16884.924
# 2     18    male  33.77  1   no  southeast   1725.5523
# 3     18    male  33.77  1   no  southeast   1725.5523
# 4     28    male   33.0  3   no  southeast    4449.462
# ...   ..     ...    ... ..  ...        ...         ...
# 2671  18  female  36.85  0   no  southeast   1629.8335
# 2672  21  female   25.8  0   no  southwest    2007.945
# 2673  21  female   25.8  0   no  southwest    2007.945
# 2674  61  female  29.07  0  yes  northwest  29141.3603
# 2675  61  female  29.07  0  yes  northwest  29141.3603
#
# [2676 rows x 7 columns]

# %% [markdown]
# ## 3.Matplotlib,Seaborn,Plotly
# - Data Visulization libraries

# %% [markdown]
# ### 3.1. Matplotlib

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# - Also we can write like this
# -> import matplotlib.pyplot as plt .

# %%
plt.hist(x=insurance_charges.age)
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 2 types of Datatypes:
# 1. Discrete - countable, it will have any unis, you can't measure that(Bar charts or dot plots)
# 2. Continous - It will have units, it is measurable(Histograms or line graphs)

# %% [markdown]
# ### 3.2. Seaborn:

# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      -------------- ----------------------- 112.6/294.9 kB 3.3 MB/s eta 0:00:01
#      ------------------------------------ - 286.7/294.9 kB 3.5 MB/s eta 0:00:01
#      -------------------------------------- 294.9/294.9 kB 3.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corr_matrix = insurance_charges.corr(numeric_only=True)

# 2. Pass the clean numeric matrix to the heatmap
sns.heatmap(data=corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
pip install plotly
# Out:
# ...
#      ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/9.9 MB 2.6 MB/s eta 0:00:04
#      - -------------------------------------- 0.4/9.9 MB 5.0 MB/s eta 0:00:02
#      -- ------------------------------------- 0.7/9.9 MB 5.7 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.2/9.9 MB 6.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.5/9.9 MB 6.6 MB/s eta 0:00:02
#      ------- -------------------------------- 1.8/9.9 MB 6.9 MB/s eta 0:00:02
#      ------- -------------------------------- 1.9/9.9 MB 7.1 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.5/9.9 MB 6.9 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.6/9.9 MB 7.0 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.7/9.9 MB 5.8 MB/s eta 0:00:02
#      ------------- -------------------------- 3.4/9.9 MB 6.8 MB/s eta 0:00:01
# ...

# %% [markdown]
# ### 3.3. Plotly Library:

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %% [markdown]
# We get this code from this link
# https://docs.plotly.com/?_gl=1*11b1y1g*_gcl_au*MTE2Nzg1MDQ2NC4xNzgwOTEzNzgx*_ga*MTYyODk2NjYwMy4xNzgwOTEzNzgx*_ga_6G7EE0JNSC*czE3ODA5MTM3ODIkbzEkZzEkdDE3ODA5MTM4MDgkajM0JGwwJGgw
#
# We can got and select the diagramic represent we want and take the code
